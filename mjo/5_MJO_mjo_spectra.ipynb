# %% [markdown]
# # MJO 5: Calculate MJO Spectra
#
# Via `mjo_spectra.ncl`

# %%
# # getenv == os.environ
import os

CASENAME = "QBOi.EXP1.AMIP.001"
startdate = '19790101'
enddate = '19811231'

# /glade/u/home/bundy/mdtf/MDTF_3_main/MDTF-diagnostics.blocking_notebook/diagnostics/MJO_suite/MJO_driver.py
#DATADIR = "/glade/u/home/bundy/diag/mdtf/inputdata/model/QBOi.EXP1.AMIP.001/"
WORK_DIR = os.getcwd()
DATADIR = "/data/"

U200_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.U200.day.nc"
V200_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.V200.day.nc"
U850_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.U850.day.nc"
V850_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.V850.day.nc"
RLUT_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.FLUT.day.nc"
PR_FILE = WORK_DIR + DATADIR + "QBOi.EXP1.AMIP.001.PRECT.day.nc"

lev_coord = "lev"
lat_coord = "lat"
lon_coord = "lon"
time_coord = "time"
pr_var = "PRECT"
rlut_var = "FLUT"

u200_var = "U200"
v200_var = "V200"

wk_dir = WORK_DIR + "/model/"

# setup data directory, if does not already exist
#if not os.path.exists(DATADIR): os.makedirs(DATADIR)

# %%
var_types = ["pr", "rlut", "u200", "u850", "v200", "v850"]

file_dir = WORK_DIR + DATADIR + "anomaly/" + CASENAME
filename_pr = file_dir  + ".prect.day.anom.nc"
filename_rlut = file_dir + ".flut.day.anom.nc"
filename_u200 = file_dir + ".u200.day.anom.nc"
filename_u850 = file_dir + ".u850.day.anom.nc"
filename_v200 = file_dir + ".v200.day.anom.nc"
filename_v850 = file_dir + ".v850.day.anom.nc"

file_list = [filename_pr, filename_rlut, filename_u200, filename_u850, filename_v200, filename_v850]

# %%
nameSeason = ["winter", "summer"]

latS = -10
latN = 10
vName = "U_anom" # name of variable on the file

pltDir = WORK_DIR + "/PS/"
pltType = "ps"

# %%
file_list = [filename_pr, filename_rlut, filename_u200, filename_u850, filename_v200, filename_v850]
file_list
# Out:
# ['/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.prect.day.anom.nc',
#  '/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.flut.day.anom.nc',
#  '/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.u200.day.anom.nc',
#  '/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.u850.day.anom.nc',
#  '/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.v200.day.anom.nc',
#  '/home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.v850.day.anom.nc']

# %%
import xarray as xr
xr.open_dataset(filename_u850)
# Out:
# <xarray.Dataset> Size: 565MB
# Dimensions:  (time: 2555, lat: 192, lon: 288)
# Coordinates:
#   * time     (time) object 20kB 1975-01-01 00:00:00 ... 1981-12-31 00:00:00
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.3 357.5 358.8
# Data variables:
#     date     (time) float64 20kB ...
#     U850     (time, lat, lon) float32 565MB ...

# %%
import matplotlib.pyplot as plt
import geocat.viz as gv

def mjo_spectra_plot(data):
    fig, ax = plt.subplots(3, 1) # L48 (mjo_spectra.ncl)

    #gv.util.add_subplot_labels(
    #    ax = ax,
    #    labels = ["a", "b"],
    #    loc="upper left" # amJust = TopLeft: L54 (mjo_spectra.ncl)
    #)

    plt.tight_layout() # L51 (mjo_spectra.ncl)

# %%
from datetime import datetime

for i, ivars in enumerate(var_types):
    pltName = CASENAME + ".MJO.wave.freq." + ivars
    print(pltName)
    
    # time indcies corresponding to the desired time window
    # L75 (mjo_spectra.ncl)
    print(file_list[i])
    var_file = xr.open_dataset(file_list[i])
    date = var_file["time"]
    date_time = date.dt.strftime("%Y%m%d") # L78 (mjo_spectra.ncl) # YYYYMMDD 
    twStrt = date.min().item() # L79 (mjo_spectra.ncl)
    twLast = date.max().item() # L80 (mjo_spectra.ncl)
    print(f"Time range from {twStrt} to {twLast}")

    # read user specific period L86 (mjo_spectra.ncl)
    # TODO: L89
    break
# Out:
# QBOi.EXP1.AMIP.001.MJO.wave.freq.pr
# /home/cs/Github/geocat-research/mjo/data/anomaly/QBOi.EXP1.AMIP.001.prect.day.anom.nc
# Time range from 1975-01-01 00:00:00 to 1981-12-31 00:00:00

# %%
#
