# %% [markdown]
# # mjo_spectra
#
# - Calculate and plot seasonal spectra via segment averaging as defined by the US-CLIVAR MJO diagnostics website
# - Internally calls: [mjo_spectra_season](https://www.ncl.ucar.edu/Document/Functions/Diagnostics/mjo_spectra_season.shtml)
# - [NCL: mjo_spectra](https://www.ncl.ucar.edu/Document/Functions/Diagnostics/mjo_spectra.shtml)
#
# [NCL Script](mjo_spectra.ncl) with output:
# <table>
#   <tr>
#     <td><img src="mjo_output/mjo_spectra_IO.png" width="500" height="300" /></td>
#     <td><img src="mjo_output/mjo_spectra_WP.png" width="500" height="300" /></td>
#   </tr>
# </table>
